# %%
x = 'Home'
x.upper()
# Out:
# 'HOME'

# %%
lower = x.upper
lower()
# Out:
# 'HOME'

# %%
lower
# Out:
# <function str.upper()>

# %%
lower_2 = x.upper()
lower_2
# Out:
# 'HOME'

# %%
from datetime import datetime, date, time, timedelta, timezone

# %%
date.today()
# Out:
# datetime.date(2025, 11, 2)

# %%
dir(date)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__replace__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'ctime',
#  'day',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'min',
#  'month',
#  'replace',
#  'resolution',
#  'strftime',
#  'timetuple',
#  'today',
#  'toordinal',
#  'weekday',
#  'year']

# %%
date.today().weekday()
# Out:
# 6

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 11, 2, 21, 0, 31, 784693)

# %%
datetime.today()
# Out:
# datetime.datetime(2025, 11, 2, 21, 1, 13, 315236)

# %%
datetime(2028, 2, 29, 21, 37)
# Out:
# datetime.datetime(2028, 2, 29, 21, 37)

# %%
now = datetime.today()
now
# Out:
# datetime.datetime(2025, 11, 2, 21, 5, 15, 37515)

# %%
yesterday = now - timedelta(days=1)
yesterday
# Out:
# datetime.datetime(2025, 11, 1, 21, 4, 21, 841393)

# %%
one_week_later = now + timedelta(weeks=1)
one_week_later
# Out:
# datetime.datetime(2025, 11, 9, 21, 5, 15, 37515)

# %%
one_year_later = now + timedelta(days=365)
one_year_later
# Out:
# datetime.datetime(2026, 11, 2, 21, 5, 15, 37515)

# %%
d = '3.2025:25'
datetime.strptime(d, '%m.%Y:%d')
# Out:
# datetime.datetime(2025, 3, 25, 0, 0)

# %%
now
# Out:
# datetime.datetime(2025, 11, 2, 21, 5, 15, 37515)

# %%
now.strftime('%m.%Y:%d')
# Out:
# '11.2025:02'

# %%
now.strftime('%B')
# Out:
# 'November'

# %%
now.strftime('%B_sth_')
# Out:
# 'November_sth_'

# %%
now.strftime('%A🔫')
# Out:
# 'Sunday🔫'

# %%
m_birthday = date(2026, 4, 12)
m_birthday - now.date()
# Out:
# datetime.timedelta(days=161)

# %%
z = m_birthday.strftime('%A, %B %d, %Y')
z
# Out:
# 'Sunday, April 12, 2026'

# %%
m_birthday.strftime('%A')
# Out:
# 'Sunday'

# %%
m_birthday.day
# Out:
# 12

# %%
m_birthday.weekday()
# Out:
# 6
