# %%
def sentence(name):
    def inner(city):
        return f'I am {name} and I come from {city}'
    return inner

# %%
sent = sentence('Mike')

# %%
res = sent('New York')

# %%
res
# Out:
# 'I am Mike and I come from New York'

# %%
sent.__closure__[0].cell_contents
# Out:
# 'Mike'

# %%
sent.__closure__
# Out:
# (<cell at 0x7c7da42348b0: str object at 0x7c7da4234930>,)

# %%
sentence.sth = 42

# %%
sentence.sth
# Out:
# 42

# %%
sentence.__code__
# Out:
# <code object sentence at 0x7c7da4127050, file "/tmp/ipykernel_5081/3723871493.py", line 1>

# %%
sent
# Out:
# <function __main__.sentence.<locals>.inner(city)>

# %%
res2 = sent('Orlando')
res2
# Out:
# 'I am Mike and I come from Orlando'
