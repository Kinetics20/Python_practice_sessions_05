# %%
any_list = [-5, -20, 19, -17, -8, 89, -59, 19, 0, 693, -542, 588, 903, -472, -16, 2, 663, -21, 47, 37, -10, -731, -5, -366, -85, 174, -89, 99, -288, 26, -7, -867, -586, -351, 92, -48]

# %%
def men_from_boys(y):
    return sorted(set(y), key=lambda x: (x % 2, x if not x % 2 else -x))

# %%
men_from_boys(any_list)
# Out:
# [-586,
#  -542,
#  -472,
#  -366,
#  -288,
#  -48,
#  -20,
#  -16,
#  -10,
#  -8,
#  0,
#  2,
#  26,
#  92,
#  174,
#  588,
#  903,
#  693,
#  663,
#  99,
#  89,
#  47,
#  37,
#  19,
#  -5,
#  -7,
#  -17,
#  -21,
#  -59,
#  -85,
#  -89,
#  -351,
#  -731,
#  -867]

# %%
sorted(any_list, key=lambda x: x % 2)
# Out:
# [-20,
#  -8,
#  0,
#  -542,
#  588,
#  -472,
#  -16,
#  2,
#  -10,
#  -366,
#  174,
#  -288,
#  26,
#  -586,
#  92,
#  -48,
#  -5,
#  19,
#  -17,
#  89,
#  -59,
#  19,
#  693,
#  903,
#  663,
#  -21,
#  47,
#  37,
#  -731,
#  -5,
#  -85,
#  -89,
#  99,
#  -7,
#  -867,
#  -351]

# %%
sorted(any_list, key=lambda x: (x % 2, x))
# Out:
# [-586,
#  -542,
#  -472,
#  -366,
#  -288,
#  -48,
#  -20,
#  -16,
#  -10,
#  -8,
#  0,
#  2,
#  26,
#  92,
#  174,
#  588,
#  -867,
#  -731,
#  -351,
#  -89,
#  -85,
#  -59,
#  -21,
#  -17,
#  -7,
#  -5,
#  -5,
#  19,
#  19,
#  37,
#  47,
#  89,
#  99,
#  663,
#  693,
#  903]

# %%
sorted(any_list, key=lambda x: (x % 2 == 0, x))
# Out:
# [-867,
#  -731,
#  -351,
#  -89,
#  -85,
#  -59,
#  -21,
#  -17,
#  -7,
#  -5,
#  -5,
#  19,
#  19,
#  37,
#  47,
#  89,
#  99,
#  663,
#  693,
#  903,
#  -586,
#  -542,
#  -472,
#  -366,
#  -288,
#  -48,
#  -20,
#  -16,
#  -10,
#  -8,
#  0,
#  2,
#  26,
#  92,
#  174,
#  588]

# %%
sorted(any_list, key=lambda x: (x % 2, x), reverse=True)
# Out:
# [903,
#  693,
#  663,
#  99,
#  89,
#  47,
#  37,
#  19,
#  19,
#  -5,
#  -5,
#  -7,
#  -17,
#  -21,
#  -59,
#  -85,
#  -89,
#  -351,
#  -731,
#  -867,
#  588,
#  174,
#  92,
#  26,
#  2,
#  0,
#  -8,
#  -10,
#  -16,
#  -20,
#  -48,
#  -288,
#  -366,
#  -472,
#  -542,
#  -586]

# %%
al = [[1,2], [3, 4]]

# %%
[x * 3 for y in al for x in y]
# Out:
# [3, 6, 9, 12]

# %%
[[x * 3 for x in item] for item in al]
# Out:
# [[3, 6], [9, 12]]

# %%
[[x * 3 for x in item if not x % 2] for item in al]
# Out:
# [[6], [12]]

# %%
list(map(lambda item: list(map(lambda x: x * 2, item)), al))
# Out:
# [[2, 4], [6, 8]]

# %%
0 == 0 % 2
# Out:
# True
