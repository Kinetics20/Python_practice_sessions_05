# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('./datasets/titanic.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = df.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'])

# %%
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    1  22.0      1      0   7.2500        S
# 1         1       1    0  38.0      1      0  71.2833        C
# 2         1       3    0  26.0      0      0   7.9250        S
# 3         1       1    0  35.0      1      0  53.1000        S
# 4         0       3    1  35.0      0      0   8.0500        S

# %%
df = pd.get_dummies(df, columns=['Embarked'])
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0         0       3    1  22.0      1      0   7.2500       False       False
# 1         1       1    0  38.0      1      0  71.2833        True       False
# 2         1       3    0  26.0      0      0   7.9250       False       False
# 3         1       1    0  35.0      1      0  53.1000       False       False
# 4         0       3    1  35.0      0      0   8.0500       False       False
#
#    Embarked_S
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True

# %%
df.shape
# Out:
# (891, 10)

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked_C  \
# 5           0       3    1  NaN      0      0   8.4583       False
# 17          1       2    1  NaN      0      0  13.0000       False
# 19          1       3    0  NaN      0      0   7.2250        True
# 26          0       3    1  NaN      0      0   7.2250        True
# 28          1       3    0  NaN      0      0   7.8792       False
# ..        ...     ...  ...  ...    ...    ...      ...         ...
# 859         0       3    1  NaN      0      0   7.2292        True
# 863         0       3    0  NaN      8      2  69.5500       False
# 868         0       3    1  NaN      0      0   9.5000       False
# 878         0       3    1  NaN      0      0   7.8958       False
# 888         0       3    0  NaN      1      2  23.4500       False
#
#      Embarked_Q  Embarked_S
# 5          True       False
# 17        False        True
# 19        False       False
# 26        False       False
# 28         True       False
# ..          ...         ...
# 859       False       False
# 863       False        True
# 868       False        True
# 878       False        True
# 888       False        True
#
# [177 rows x 10 columns]

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (714, 10)

# %%
df_feature = df.drop(columns=['Survived'])
df_labels = df['Survived']

# %%
bandwidth = estimate_bandwidth(df_feature)
bandwidth
# Out:
# np.float64(30.43381713199512)

# %%
model = MeanShift(bandwidth=30, n_jobs=-1)
model.fit(df_feature)
# Out:
# MeanShift(bandwidth=30, n_jobs=-1)

# %%
labels = model.labels_
np.unique(labels)
# Out:
# array([0, 1, 2, 3, 4])

# %%
analyser = MeanShift(bandwidth=bandwidth, n_jobs=-1)
analyser.fit(df)
# Out:
# MeanShift(bandwidth=np.float64(30.43381713199512), n_jobs=-1)

# %%
labels = model.labels_
np.unique(labels)
# Out:
# array([0, 1, 2, 3, 4])

# %%
df['cluster_group'] = labels
# Out:
# /tmp/ipykernel_8795/4067143167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cluster_group'] = labels

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  714.000000  714.000000  714.000000  714.000000  714.000000  714.000000
# mean     0.406162    2.236695    0.634454   29.699118    0.512605    0.431373
# std      0.491460    0.838250    0.481921   14.526497    0.929783    0.853289
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    1.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    2.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    1.000000
# max      1.000000    3.000000    1.000000   80.000000    5.000000    6.000000
#
#              Fare  cluster_group
# count  714.000000     714.000000
# mean    34.694514       0.317927
# std     52.918930       0.691392
# min      0.000000       0.000000
# 25%      8.050000       0.000000
# 50%     15.741700       0.000000
# 75%     33.375000       0.000000
# max    512.329200       4.000000

# %%
df_cluster_data = df.groupby(['cluster_group']).mean()

# %%
df_cluster_data['Counts'] = df.groupby(['cluster_group']).size()

# %%
df_cluster_data
# Out:
#                Survived    Pclass       Sex        Age     SibSp     Parch  \
# cluster_group
# 0              0.334532  2.528777  0.679856  28.218076  0.438849  0.368705
# 1              0.618182  1.300000  0.527273  36.200000  0.809091  0.509091
# 2              0.733333  1.000000  0.366667  32.430667  0.600000  0.866667
# 3              0.733333  1.000000  0.266667  30.333333  1.000000  1.333333
# 4              1.000000  1.000000  0.666667  35.333333  0.000000  0.333333
#
#                      Fare  Embarked_C  Embarked_Q  Embarked_S  Counts
# cluster_group
# 0               15.351026    0.118705    0.046763    0.834532     556
# 1               65.130268    0.345455    0.018182    0.618182     110
# 2              131.183883    0.500000    0.000000    0.500000      30
# 3              239.991940    0.533333    0.000000    0.466667      15
# 4              512.329200    1.000000    0.000000    0.000000       3

# %%
df.loc[df['cluster_group'] == 0].describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  556.000000  556.000000  556.000000  556.000000  556.000000  556.000000
# mean     0.334532    2.528777    0.679856   28.218076    0.438849    0.368705
# std      0.472252    0.655592    0.466952   14.077084    0.891320    0.797988
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   19.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   27.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   36.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    4.000000    5.000000
#
#              Fare  cluster_group
# count  556.000000          556.0
# mean    15.351026            0.0
# std      9.064108            0.0
# min      0.000000            0.0
# 25%      7.895800            0.0
# 50%     12.412500            0.0
# 75%     24.000000            0.0
# max     41.579200            0.0

# %%
df.loc[df['cluster_group'] == 0]
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  \
# 0           0       3    1  22.0      1      0   7.2500       False
# 2           1       3    0  26.0      0      0   7.9250       False
# 4           0       3    1  35.0      0      0   8.0500       False
# 7           0       3    1   2.0      3      1  21.0750       False
# 8           1       3    0  27.0      0      2  11.1333       False
# ..        ...     ...  ...   ...    ...    ...      ...         ...
# 885         0       3    0  39.0      0      5  29.1250       False
# 886         0       2    1  27.0      0      0  13.0000       False
# 887         1       1    0  19.0      0      0  30.0000       False
# 889         1       1    1  26.0      0      0  30.0000        True
# 890         0       3    1  32.0      0      0   7.7500       False
#
#      Embarked_Q  Embarked_S  cluster_group
# 0         False        True              0
# 2         False        True              0
# 4         False        True              0
# 7         False        True              0
# 8         False        True              0
# ..          ...         ...            ...
# 885        True       False              0
# 886       False        True              0
# 887       False        True              0
# 889       False       False              0
# 890        True       False              0
#
# [556 rows x 11 columns]

# %%
n_clusters = len(np.unique(model.labels_))
n_clusters
# Out:
# 5

# %%
model.cluster_centers_
# Out:
# array([[2.56250000e+00, 6.68560606e-01, 2.70279356e+01, 4.28030303e-01,
#         3.86363636e-01, 1.50454616e+01, 1.23106061e-01, 4.35606061e-02,
#         8.33333333e-01],
#        [1.34000000e+00, 5.30000000e-01, 3.34800000e+01, 8.30000000e-01,
#         5.00000000e-01, 6.28027530e+01, 3.10000000e-01, 2.00000000e-02,
#         6.60000000e-01],
#        [1.00000000e+00, 4.16666667e-01, 3.24166667e+01, 6.25000000e-01,
#         7.50000000e-01, 1.25112492e+02, 5.83333333e-01, 0.00000000e+00,
#         4.16666667e-01],
#        [1.00000000e+00, 2.00000000e-01, 2.77000000e+01, 1.40000000e+00,
#         1.20000000e+00, 2.49136660e+02, 7.00000000e-01, 0.00000000e+00,
#         3.00000000e-01],
#        [1.00000000e+00, 6.66666667e-01, 3.53333333e+01, 0.00000000e+00,
#         3.33333333e-01, 5.12329200e+02, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00]])
